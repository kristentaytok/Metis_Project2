# %%
# #for Selenium
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
# import time
# from selenium.webdriver.chrome.options import Options
# #to help loop back to main page:
# import selenium.webdriver.support.ui as ui

# #for BeautifulSoup
# from bs4 import BeautifulSoup
# import re

# import pandas as pd
# import os

# import chromedriver_binary


# driver = webdriver.Chrome()
# #driver.get('https://www.airbnb.com/s/classes/experiences?refinement_paths%5B%5D=%2Fexperiences%2FKG%2FTag%3A12&screen_size=large&search_type=search_query')
# driver.get("https://www.airbnb.com/s/crafts-classes/experiences?refinement_paths%5B%5D=%2Fexperiences&screen_size=large&search_type=search_query")
# # #driver.get('https://www.airbnb.com/experiences/1029847?location=Craft%20class&source=p2') 

start_page_list = []
start_page_dict = {}

for url in driver.find_elements_by_class_name('_1s5t6bf8'):
    #Dictionary of url's (to merge with other list)
    urls = []
    url_selector = driver.find_elements_by_xpath('//a[@href]')
    urls = [x.get_attribute("href") for x in url_selector] 
    del urls[:2]
    urls.pop()
    start_page_dict['URLs'] = urls
    
    #Dictionary of categories
    category_selector = driver.find_elements_by_class_name('_13qcgpja')
    categories = [x.text for x in category_selector] 
    start_page_dict['Categories'] = categories
    
    #Dictionary of prices
    price_selector = driver.find_elements_by_xpath('//div/div/a/div/div[2]/div[1]/div[3]/div/div/ul/li[1]')
    prices = [x.text for x in price_selector] 
    start_page_dict['Prices'] = prices
    
    #Dictionary of ratings, which has a list (rating_value_list) as its value. Lists are ordered and can contain repeats, which is great when there are repeat ratings.   
    rating_value_list = []
    all_listings_ratings_section_selector = driver.find_elements_by_class_name('_1sny8g3')
    for ratings_section in all_listings_ratings_section_selector:
        if ratings_section.text == '':
            rating_value_list.append('n/a')
        else:
            rating_value_list.append(ratings_section.text)          
    start_page_dict['Ratings'] = rating_value_list
    
    #Dictionary of experience durations
    duration_value_list = []
    
    all_listings_durations_section_selector = driver.find_elements_by_class_name('_fgby1rh')
    for durations_section in all_listings_durations_section_selector:
        duration_value_list.append(durations_section.text) 
    start_page_dict['Durations'] = duration_value_list
#     duration_selector = driver.find_elements_by_xpath('//div/div/a/div/div[2]/div[1]/div[3]/div/div/ul/li[2]')
#     durations = [x.text for x in duration_selector] 
#     start_page_dict['Durations'] = durations
    
    #Dictionary of titles
    title_selector = driver.find_elements_by_class_name('_1s5t6bf8')
    titles = [x.text for x in title_selector]
    start_page_dict['Titles'] = titles
    
    #Append all dictionaries to start_page_list
    
    
    break

#create pandas dataframe from dictionaries
start_page_df = pd.DataFrame(start_page_dict)
start_page_df
# Out:
#                                                  URLs  \
# 0   https://www.airbnb.com/s/crafts-classes/experi...
# 1   https://www.airbnb.com/experiences/223773?loca...
# 2   https://www.airbnb.com/experiences/421409?loca...
# 3   https://www.airbnb.com/experiences/358969?loca...
# 4   https://www.airbnb.com/experiences/1140666?loc...
# 5   https://www.airbnb.com/experiences/522186?loca...
# 6   https://www.airbnb.com/experiences/1005288?loc...
# 7   https://www.airbnb.com/experiences/340384?loca...
# 8   https://www.airbnb.com/experiences/421213?loca...
# 9   https://www.airbnb.com/experiences/817341?loca...
# 10  https://www.airbnb.com/experiences/1135343?loc...
# 11  https://www.airbnb.com/experiences/1146053?loc...
# 12  https://www.airbnb.com/experiences/497078?loca...
# 13  https://www.airbnb.com/experiences/276739?loca...
# 14  https://www.airbnb.com/experiences/319392?loca...
# 15  https://www.airbnb.com/experiences/532337?loca...
# ...

# %%
driver//*[@id="site-content"]/div/div/div/div[4]/div/div/div/div[2]/div/div/div/div[2]/div/div/div[1]/div/div/a
//*[@id="site-content"]/div/div/div/div[4]/div/div/div/div[2]/div/div/div/div[2]/div/div/div[2]/div/div/a

//*[@id="site-content"]/div/div/div/div[4]/div/div/div/div[2]/div/div/div/div[2]/div/div/div[2]/div/div/a/div/div[2]/div[1]/div[3]/div/div/ul/li[1]
<a href="/experiences/223773?location=crafts%20classes&amp;currentTab=experience_tab&amp;federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&amp;searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&amp;sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&amp;source=p2" target="_blank" class="_d69rnt" aria-busy="false"><div class="_1yfus1e" role="text"><div><div style="margin-bottom: 12px;"><div class="_13ky0r6y" style="padding-top: 133.333%; background: none;"><div class="_1szwzht"><div class="_kowt4i"><div class="_hxt6u1e" style="padding-top: 133.333%;"><div class="_4626ulj"><img class="_91slf2a" aria-hidden="true" alt="" decoding="async" src="https://a0.muscache.com/im/pictures/45a7e80e-aadf-4cc4-bfaa-361034b85218.jpg?aki_policy=poster" style="object-fit: cover;"><div class="_10xjrv2u" style="background-image: url(&quot;https://a0.muscache.com/im/pictures/45a7e80e-aadf-4cc4-bfaa-361034b85218.jpg?aki_policy=poster&quot;); background-size: cover;"></div></div></div></div><div class="_1f1b4xge"><div></div></div><div class="_1ed5wud"></div></div></div></div></div><div><div><div style="margin-bottom: 2px;"><div class="_13qcgpja" title="workshop">workshop</div></div><div class="_1s5t6bf8" title="Thai Traditional Yantra Tattoo.">Thai Traditional Yantra Tattoo.</div><div style="margin-top: 4px;"><div class="_fgby1rh" title="From $85/person · 5 hours"><div class="_36rlri"><ul class="_11hau3k"><li class="_g86r3e">From $85/person</li><li class="_g86r3e"> <span aria-hidden="true">·</span> 5 hours</li></ul></div></div></div></div><div class="_1sny8g3"><div class="_g9xtsw7"><div class="_1iv05u9z"><div class="_1r3fg0" aria-label="Rating 4.99 out of 5" role="img"><div class="_1julapm"><div style="margin-right: 2px;"><div class="_s667uw2">4.99</div></div></div><div class="_hd1745c"><span role="img" aria-label="Rating 1 out of 5" class="_m5wjo84" style="width: 10px;"><span class="_83zdpk"><span class="_ogu8zgi" style="width: 10px;"></span></span></span></div></div><span class="_krjbj">203 reviews</span><div class="_1julapm" aria-hidden="true"><span class="_1plk0jz1">(203)</span></div></div></div></div></div></div></a>

# %%
# duration_value_list = []
# #<li class="_g86r3e"> <span aria-hidden="true">·</span> <!-- -->2 hours</li>
# all_listings_durations_section_selector = driver.find_elements_by_class_name('_fgby1rh')
# for durations_section in all_listings_durations_section_selector:
#     duration_value_list.append(durations_section.text) 
# print(len(duration_value_list))
# duration_value_list
url_test = driver.current_url
url_test

# %%
#Append all dictionaries to start_page_list

# start_page_list = []
# start_page_dict = {}

# for url in driver.find_elements_by_class_name('_1s5t6bf8'):
#     #Dictionary of url's (to merge with other list)
#     url_selector = driver.find_elements_by_xpath('//a[@href]')
#     urls = [x.get_attribute("href") for x in url_selector] 
#     del urls[:2]
#     urls.pop()
#     start_page_dict['URLs'] = urls

#     break
print(len(start_page_dict['URLs']))
print(len(start_page_dict['Durations']))
print(len(start_page_dict['Prices']))
print(len(start_page_dict['Ratings']))

print(len(start_page_dict['Titles']))
start_page_dict['URLs']
# Out:
# 19
# 18
# 18
# 18
# 18
# ['https://www.airbnb.com/s/crafts-classes/experiences?refinement_paths%5B%5D=%2Fexperiences%2FKG%2FTag%3A12&screen_size=large&search_type=unknown&query=Craft%20classes',
#  'https://www.airbnb.com/experiences/223773?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=af5f4cce-f11a-4b96-af89-2acdfbcca44b&searchId=c1d8ebd9-3768-4287-87cd-ff2ab6bc275a&sectionId=ca0384d8-0c0c-43d0-a8e6-665a4e0c8abf&source=p2',
#  'https://www.airbnb.com/experiences/421409?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=af5f4cce-f11a-4b96-af89-2acdfbcca44b&searchId=c1d8ebd9-3768-4287-87cd-ff2ab6bc275a&sectionId=ca0384d8-0c0c-43d0-a8e6-665a4e0c8abf&source=p2',
#  'https://www.airbnb.com/experiences/358969?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=af5f4cce-f11a-4b96-af89-2acdfbcca44b&searchId=c1d8ebd9-3768-4287-87cd-ff2ab6bc275a&sectionId=ca0384d8-0c0c-43d0-a8e6-665a4e0c8abf&source=p2',
# ...

# %%
start_page_df.head()

# %%
start_page_pickle = start_page_df.to_pickle('./dummy.pkl')

# %%
unpickled_start_page_df = pd.read_pickle("./dummy.pkl")

# %%
unpickled_start_page_df

# %%
#unpickled_start_page_df_test = unpickled_start_page_df
#unpickled_start_page_df_test['Ratings_spliced'] = unpickled_start_page_df_test['Ratings'].apply(lambda x: x.split('\n')[0])
#df['a'] = df['a'].apply(lambda x: x.split('-')[0])
#unpickled_start_page_df_test['Durations_spliced'] = unpickled_start_page_df_test['Durations'].apply(lambda x: x.split('· ')[1])
#unpickled_start_page_df_test['Prices_spliced_from'] = unpickled_start_page_df_test['Prices'].apply(lambda x: x.split('From ')[1])
#unpickled_start_page_df_test['Prices_spliced_person'] = unpickled_start_page_df_test['Prices_spliced_from'].apply(lambda x: x.split('/person')[0])
unpickled_start_page_df_test = unpickled_start_page_df_test.to_pickle('./dummy.pkl')

# %%
unpickled_start_page_df_final = pd.read_pickle("./dummy.pkl")
unpickled_start_page_df_final

# %% [markdown]
# # --- Page Loops ---

# %%
# # driver.window_handles
# driver.switch_to.window(driver.window_handles[1])
# driver.find_elements_by_xpath('//*[@id="Section5"]/div/div/div/div/section/div/div/div/div/div/div[3]/div/div[2]/div[2]/div[2]')
tags = driver.find_elements_by_class_name('_9grdxv')
print(tags)

# %%
#if statement --> break
#python_button = driver.find_elements_by_xpath('//*[@id="site-content"]/div/div/div/div[4]/div/div/div/div[2]/div/div/div/div[2]/div/div/div')
#python_button = driver.find_elements_by_class_name('_1s5t6bf8')

#---CAN'T LOOP/GRAB NEXT PAGE, CLOSE----
# python_button = driver.find_elements_by_class_name('_1f1b4xge')

# for url in python_button:
#     url.click()
#     #pause between clicks to each url on the page
#     time.sleep(10)
#     #switch driver to new window 
#     window_after = driver.window_handles[1]
#     driver.switch_to.window(window_after)
    
List_of_URLs = ['https://www.airbnb.com/experiences/223773?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/358969?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1140666?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/522186?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1005288?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1135343?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1146053?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1167075?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/518579?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/532337?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/381045?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1170679?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/944051?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1012855?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/813891?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/421213?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/336926?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/736020?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/421409?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/340384?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/319392?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/497078?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/876733?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/276739?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/859712?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/370993?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/325634?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/718947?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/776320?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/944802?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1080377?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/486302?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/336980?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/311706?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/900773?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/327057?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/438982?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/835015?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1117442?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/525111?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1045939?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1030435?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/476472?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/666070?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1169381?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/875018?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1129898?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/248699?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/696847?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1161085?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/367104?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1025104?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/814392?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/710569?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1026475?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/543779?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1173838?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1091730?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/334638?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1142190?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1026293?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/384169?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/752407?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1129477?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/595557?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/573089?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/930502?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1205246?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/548809?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/260734?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/573914?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/928571?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/384173?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/662323?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/429016?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/297754?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/334569?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1152738?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/366131?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/494628?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/395932?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/768744?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/890515?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/371405?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/223915?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/284194?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/845135?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/371378?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/834983?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/436339?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/70481?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/208012?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/788080?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1029847?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1102070?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/977071?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/419041?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/583904?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/598847?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/235250?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/427770?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/745019?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/901332?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/714893?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1143008?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/742778?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1025472?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/594584?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/941755?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/978767?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/422722?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1136269?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/275285?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1125357?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/856116?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1186210?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/311506?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/389088?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/394438?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1098913?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1180042?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1025198?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/900725?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/842118?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/265197?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/744812?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/916501?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/308030?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/394438?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/469309?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/166172?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/984444?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1032242?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/344906?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/545006?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/882232?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/951968?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/455203?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/781929?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1098913?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/298017?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/802693?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/788080?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/924629?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1106040?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1191112?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1153926?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/829637?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1172272?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/485885?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/891727?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1093299?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/536840?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/569844?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/838088?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1190473?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1176847?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1185575?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/792784?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/879382?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/454331?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/741865?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1190473?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1176847?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/879382?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/765152?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/537899?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1086401?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1125475?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/458885?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/803572?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1123668?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/961098?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/820631?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1102596?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/739799?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/485885?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/700862?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/952900?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/918567?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1215626?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/333087?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/534355?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/801674?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/605947?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/897208?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/781929?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/652790?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1174541?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/607697?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/349600?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/686909?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/243503?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/778654?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/552852?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1086059?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/670797?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/205614?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1195076?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/306495?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/912947?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/408282?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/841426?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1041103?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/180159?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/435212?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1192214?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/835365?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/985353?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/454331?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1195139?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1144160?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1207469?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/356340?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/992527?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/545933?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/957065?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/715782?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1061789?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/722750?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/627185?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/750711?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1165850?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/743262?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/364949?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/540264?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/323337?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1213279?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/634481?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1056280?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1151485?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1086126?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/497478?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/567247?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1118272?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/678302?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1195076?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/628525?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1088232?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/652790?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/748105?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1179460?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/714571?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1096241?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1169623?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1124629?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1042831?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/750497?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/955832?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/532798?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/344856?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1016622?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/224977?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1198803?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1174011?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/704897?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/531019?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/507230?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/241625?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/792784?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1175788?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/818938?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/948021?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1163471?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/541816?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1049072?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/286620?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/154886?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1213279?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1100536?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1100536?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/564577?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/958601?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/775482?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/166172?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/725602?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/272903?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1155126?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/795689?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/735643?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/613135?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/314318?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/721663?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/924170?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/306295?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1183005?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/425425?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/834294?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/790112?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/685007?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/805176?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1122652?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/161602?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1026070?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/991728?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1179460?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1157992?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/967424?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/401208?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1167857?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/734608?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/913537?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/763541?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/417821?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/612422?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1083883?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1141687?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1053389?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/951003?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/255113?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/950271?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/744080?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/599829?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1064965?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1119382?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1173232?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/398376?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1068719?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/329410?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/305187?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/437698?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/434822?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/559291?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/347909?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/347909?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/715908?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/984677?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/117290?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/929000?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/433696?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/808836?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/786201?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/408242?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1199987?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/623473?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/771168?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1081010?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1124629?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1083901?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1206874?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/560296?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1120477?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/663827?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1164602?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1118272?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/698491?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1098030?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1170612?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/651843?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1086757?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1162441?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/722170?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1072080?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1124318?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/704597?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/843845?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/303480?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1061789?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/773273?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1166327?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1086757?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/729669?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1062035?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/328770?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/935330?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/279031?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/551165?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/816119?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/537605?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/261015?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1155240?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/599107?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/639861?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/773273?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/900556?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/661896?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1079530?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/650811?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/780150?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1048917?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1141687?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1150607?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/485863?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/756695?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/113490?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/469534?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1122769?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/257938?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1093742?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/722001?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/723615?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/516458?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1096068?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/344111?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/388137?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/199321?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/773979?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/697045?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/967446?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/904288?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/799853?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1065508?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/978215?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/647476?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/374712?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/557690?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/881947?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/313528?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/574004?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/758435?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/829852?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1042274?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1083901?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/747389?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/281328?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/881947?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/313528?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1150607?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/345566?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/723615?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/829852?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1042274?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/599107?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/747389?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1202066?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/364493?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/511102?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/864379?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1050326?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/592698?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/746261?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/842349?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/842349?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1104992?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/814408?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1131955?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1099758?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1218569?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/651860?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1205835?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/79228?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/787387?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1033511?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/436797?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/799853?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/510369?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1005990?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/162691?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/998794?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/772604?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1201855?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1154589?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/981992?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/246535?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/904153?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1037837?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/694807?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/118848?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1132877?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1136770?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/735610?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1197522?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1000433?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/984677?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/374119?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/612422?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1147428?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/281328?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1126045?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/748105?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1000433?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1147428?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/574004?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/864821?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1089253?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1120383?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/693377?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/957928?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/756695?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1071885?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/580039?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/886456?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/556702?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/560135?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1182692?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/889362?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/330181?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1076810?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1197913?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1149813?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1193796?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/367388?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/970561?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/267246?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/170253?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1183395?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/930768?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1085826?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/388901?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/820237?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/726170?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/894584?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/633231?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1063402?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1063402?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/260680?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/376610?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1164059?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1104992?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/904480?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/92459?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/434822?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1118044?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/575215?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/792153?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1174649?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/305187?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/349831?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/592698?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1150820?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/447012?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/900443?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/900443?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/17522?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/882088?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/764760?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/834808?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/388808?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1173212?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/978215?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/309897?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/344906?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/893946?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/624221?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1153221?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/820237?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/500435?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/84476?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/580443?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1042154?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/875017?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1036901?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/408501?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/65414?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/352205?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/758435?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/396074?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1067762?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1169242?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/885475?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/521391?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/931987?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/722302?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/683252?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/131222?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1218970?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/993936?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1214161?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1163588?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1168522?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/772910?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/949873?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/566632?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1154265?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/726031?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1199588?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/958835?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/930768?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/602620?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/250994?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/301120?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/774020?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/381734?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1021879?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/660332?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/584489?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/660332?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/584489?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/836220?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/942741?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1150654?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1067990?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/762737?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/289076?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/326013?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/427467?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/514932?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1142508?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1195579?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/279778?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1049640?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/210599?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/807401?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/580824?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/908350?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/476363?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/364041?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/947702?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/970561?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/264432?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/984178?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/781580?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1193855?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/325813?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/804024?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/342130?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/295964?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1125952?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1111217?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1067586?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/932861?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/955680?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1125952?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1067586?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1148385?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/336626?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/932861?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/955680?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/903786?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1200236?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/209198?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1148014?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/876865?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/549474?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/703578?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/178511?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1099485?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/559876?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1130898?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/709123?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/624198?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/517429?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/486029?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/374151?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/971063?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/607831?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/804853?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1217475?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/359674?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1187760?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/268056?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/961108?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/778092?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/353026?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/503588?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/947702?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/830360?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/800215?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1065002?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/875405?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1111217?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/421172?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1158495?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/804024?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/852602?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1018946?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/774046?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1087719?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/494301?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/933025?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/793635?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/777253?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1076255?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1182950?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1168092?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/227286?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/317334?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1182950?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1168092?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/891277?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1062155?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/629610?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/438915?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1182247?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/226444?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/735610?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/349831?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/308129?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1019263?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/471248?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/308585?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/903786?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/903318?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/709399?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/629610?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/802003?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1067991?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/342807?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/580824?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/220404?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/992391?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/286989?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/737682?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/791778?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/850718?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/427467?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1168947?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/571086?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/206040?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1067762?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/484609?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/661795?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/556324?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/484609?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/172494?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/661795?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/519719?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1001051?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/21576?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/788027?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/642832?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/839075?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/251590?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/242309?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/778092?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/914719?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1020048?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/396196?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/676946?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1177436?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/942741?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/190482?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/874728?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/400488?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1177436?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/738381?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/434679?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/644427?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/306912?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1199588?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/867209?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/866581?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/633155?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/396196?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/503036?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/774020?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/610986?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/971612?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1045620?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/569757?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1150850?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/381593?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1160725?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/788027?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/474054?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/734765?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/661496?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/985162?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1021985?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1181090?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/298331?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/132170?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/112349?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1145736?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/388377?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/901681?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/388377?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/901681?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/517394?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/471910?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/103458?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/510930?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/613837?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1186048?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/593641?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/912483?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/428238?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1083552?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/877322?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/763829?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/905579?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1085817?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/910767?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/226761?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/310372?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/802003?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/731458?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/970783?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/800428?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/132170?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1199934?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/703860?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1193660?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/353482?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/778038?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/890067?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/153115?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/987913?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1118944?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/170253?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1107171?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1108504?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1041268?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1159696?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1089631?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/281987?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/369831?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1009810?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/411037?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1173975?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/984143?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/550746?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/21576?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1060075?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1185608?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/872395?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/490354?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/939903?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1159860?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/745273?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1089631?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1159860?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/745273?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/678572?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/945143?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/866581?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/411037?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/619036?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1206745?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1190724?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/328542?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/360126?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/855619?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1069057?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/399839?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/684234?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/517358?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/585827?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/788826?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/738381?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/897261?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1157804?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/310607?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/858557?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/826159?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/89730?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/771000?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/713323?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/280678?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/357349?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/571086?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1188207?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/277161?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/200979?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1027725?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/800844?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/800844?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/662215?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/89730?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/410253?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/955302?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1119831?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/339244?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/59546?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/951680?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/843993?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/251673?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/655753?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/860742?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1061077?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/381816?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/878361?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/704294?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/754762?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1076409?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/380139?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/377804?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/241586?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/323903?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/789412?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1065639?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1058068?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1002279?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/467981?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/602662?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/869996?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/453636?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/357349?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/378990?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1175674?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/979659?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1169116?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1169116?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/719143?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/245554?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/356665?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/506681?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/350811?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/887648?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/832969?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/621197?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/933745?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1053027?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1144917?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/409056?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/917634?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/329685?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/955889?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/527980?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1126045?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1200092?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/727569?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/144656?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/821401?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/571858?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1063223?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1200488?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1070444?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1157804?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/299565?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/999849?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/533216?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/684234?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1030240?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/820267?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1062671?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/794273?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/747275?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/296500?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/831475?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1201836?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1058068?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/573037?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/760527?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/778690?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/846290?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1046976?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/769966?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/296322?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1045715?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1039409?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/227286?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/664954?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/645978?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/459489?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/537758?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/459489?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/537758?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/356902?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/400965?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/376351?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/402629?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/730297?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/144656?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1148244?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1139632?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/380842?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1057789?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1089793?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/469894?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/840605?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/13074?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/263883?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1148385?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/550666?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/884634?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/495562?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/668324?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/778690?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/255889?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/972748?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1122702?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1022335?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1105593?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/310607?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/296500?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1011145?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/945143?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/438915?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/296832?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/225907?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/478327?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/899458?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1210575?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1085826?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/608730?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1186048?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/68858?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/184102?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1173975?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/117374?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1022335?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/206613?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1105593?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/420651?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/138052?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1187584?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/791999?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1034382?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/625735?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/849810?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/540642?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/809698?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1212487?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/987937?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/278438?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/225907?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/1158495?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/93984?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2',
 'https://www.airbnb.com/experiences/377804?location=crafts%20classes&currentTab=experience_tab&federatedSearchId=247aafc3-fb5e-4744-be2d-ceb1067a3f05&searchId=fc9834a2-07e4-4fd7-b7fb-b36b42e9cf6a&sectionId=fd6a7000-ec74-467c-b26e-b3dd8038ab1c&source=p2']

listing_list = []
for url in List_of_URLs:
    driver.get(url)
    #pause between clicks to each url on the page
    time.sleep(10)
    
    #create a list of dictionaries for each page
    listing_dict = {}
    
    #URLs
    listing_dict['URLs'] = driver.current_url
        
    #number of tags
    if len(driver.find_elements_by_class_name('_9grdxv')) > 0:
        tag_selector = len(driver.find_elements_by_class_name('_9grdxv'))
        listing_dict['Tags'] = tag_selector-1
    #listing_list.append(listing_dict)
    
    #group size
    if len(driver.find_elements_by_class_name('_17zvmwh2')) > 0:
        for actual_groupsize in driver.find_elements_by_class_name('_17zvmwh2'):
            if 'Up to' in actual_groupsize.text:
                listing_dict['GroupSize'] = actual_groupsize.text
    elif len(driver.find_elements_by_class_name('_czm8crp')) > 0:
        for actual_groupsize in driver.find_elements_by_class_name('_czm8crp'):
            if 'Up to' in actual_groupsize.text:
                listing_dict['GroupSize'] = actual_groupsize.text
    #else:
                #listing_dict['GroupSize'] = 'n/a'
    
    #photo_count
    if len(driver.find_elements_by_xpath('//*[@id="FMP-target"]')) > 0:
        photo_count_selector = len(driver.find_elements_by_xpath('//*[@id="FMP-target"]'))
    elif len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div')) > 0:
        #len 2 ~ slideshow, 1 ~ static image
        photo_count_selector = len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div'))
    else:
        photo_count_selector = 0
    listing_dict['Host_photos'] = photo_count_selector
    #//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]/div/button[2] (slider/slideshow, example https://www.airbnb.com/experiences/421213?location=crafts%20classes&source=p2)
    #//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div/div/div/div/div/img (static, example https://www.airbnb.com/experiences/319392?location=crafts%20classes&source=p2 OR https://www.airbnb.com/experiences/1172272?location=crafts%20classes&source=p2)
    #previous: //*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]
    
    #included foods/drinks
    if len(driver.find_elements_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div')) > 0:
        for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div'):
            if driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div').text == 'Drinks':
                listing_dict['Drinks'] = 1
            elif driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div').text == 'Food':
                listing_dict['Food'] = 1
        for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div'):
            if driver.find_element_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div').text == 'Drinks':
                listing_dict['Drinks'] = 1
            elif driver.find_element_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div').text == 'Food':
                listing_dict['Food'] = 1
        for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div'):
            if driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div').text == 'Drinks':
                listing_dict['Drinks'] = 1
            elif driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div').text == 'Food':
                listing_dict['Food'] = 1
        for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-3"]/div/div[1]/div'):
            if driver.find_element_by_xpath('//*[@id="amenities-card-3"]/div/div[1]/div').text == 'Drinks':
                listing_dict['Drinks'] = 1
            elif driver.find_element_by_xpath('//*[@id="amenities-card-3"]/div/div[1]/div').text == 'Food':
                listing_dict['Food'] = 1
        for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-4"]/div/div[1]/div'):
            if driver.find_element_by_xpath('//*[@id="amenities-card-4"]/div/div[1]/div').text == 'Drinks':
                listing_dict['Drinks'] = 1
            elif driver.find_element_by_xpath('//*[@id="amenities-card-4"]/div/div[1]/div').text == 'Food':
                listing_dict['Food'] = 1
        for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-5"]/div/div[1]/div'):
            if driver.find_element_by_xpath('//*[@id="amenities-card-5"]/div/div[1]/div').text == 'Drinks':
                listing_dict['Drinks'] = 1
            elif driver.find_element_by_xpath('//*[@id="amenities-card-5"]/div/div[1]/div').text == 'Food':
                listing_dict['Food'] = 1
        #<div class="_h6avcp2">Drinks<!-- --> <span class="_8tbpu3" aria-hidden="true">󲀃</span></div>
    elif len(driver.find_elements_by_class_name('_h6avcp2')) > 0:
        for included_selector in driver.find_elements_by_class_name('_h6avcp2'):
            drink_count = 0
            food_count = 0
            if 'Drinks' in included_selector.text:     
            #for drink_selector in driver.find_elements_by_class_name('_h6avcp2'):
                #count = 0
            #if 'Drinks' in actual_drink_selector.text:
             #       count += 1
              #  else:
            #        count += 0
                drink_count += 1

        #print(driver.find_element_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div').text)
            if drink_count == 1:
                listing_dict['Drinks'] = 1
                
            if 'Food' in included_selector.text:
                food_count += 1
    #print(driver.find_element_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div').text)
            if food_count == 1:
                listing_dict['Food'] = 1
        #for lang_selector in driver.find_elements_by_class_name('Drinks'):
            #if driver.find_element_by_class_name('_h6avcp2').text == 'Drinks':
                #drinks = driver.find_element_by_class_name('_h6avcp2')
            #print('Drinks:'+str(count)) 
            #print('Food:'+str(count))
            #elif driver.find_element_by_class_name('_h6avcp2').text == 'Food':
                #food = driver.find_element_by_class_name('_h6avcp2')
                #print('Drinks: n/a')
                #print('Food: 1')
        #elif len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]')) > 0:
        #photo_count = len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]'))
    else:
        listing_dict['Drinks'] = 'n/a'
        listing_dict['Food'] = 'n/a'
    
    #number of languages    
    if len(driver.find_elements_by_class_name('_rk98a2')) > 0: 
        for actual_lang_selector in driver.find_elements_by_class_name('_rk98a2'):
            if 'Hosted' in actual_lang_selector.text:     
                for lang_selector in driver.find_elements_by_class_name('_17zvmwh2'):

                    count = 0
                    lang_list = ['Hungarian', 'Finnish', 'Swedish', 'Tagalog', 'Polish', 'Sign', 'Punjabi', 'Bengali', 'Dutch', 'Turkish', 'Hindi', 'Chinese', 'Mandarin', 'Russian', 'Japanese', 'French', 'Czech', 'Norwegian', 'Danish', 'Malay', 'Hebrew', 'Greek', 'Thai', 'Korean', 'Indonesian', 'Portuguese', 'Arabic', 'Spanish', 'Italian', 'German', 'English']    
                    if 'English' in lang_selector.text:
                        count += 1
                    if 'German' in lang_selector.text:
                        count += 1
                    if 'Italian' in lang_selector.text:
                        count += 1
                    if 'Spanish' in lang_selector.text:
                        count += 1
                    if 'Arabic' in lang_selector.text:
                        count += 1
                    if 'Portuguese' in lang_selector.text:
                        count += 1
                    if 'Indonesian' in lang_selector.text:
                        count += 1
                    if 'Korean' in lang_selector.text:
                        count += 1
                    if 'Thai' in lang_selector.text:
                        count += 1
                    if 'Greek' in lang_selector.text:
                        count += 1
                    if 'Hebrew' in lang_selector.text:
                        count += 1
                    if 'Malay' in lang_selector.text:
                        count += 1
                    if 'Danish' in lang_selector.text:
                        count += 1
                    if 'Norwegian' in lang_selector.text:
                        count += 1
                    if 'Czech' in lang_selector.text:
                        count += 1
                    if 'French' in lang_selector.text:
                        count += 1
                    if 'Japanese' in lang_selector.text:
                        count += 1
                    if 'Russian' in lang_selector.text:
                        count += 1
                    if 'Chinese' in lang_selector.text:
                        count += 1
                        #^^^this is a modification of Airbnb list 'Chinese (Simplified)', since I'm using an 'in' statement--which should cover all listings with the word 'Chinese'
                    if 'Mandarin' in lang_selector.text:
                        count += 1
                        #^^^this is a guess of how it can be displayed 
                    if 'Hindi' in lang_selector.text:
                        count += 1
                    if 'Turkish' in lang_selector.text:
                        count += 1
                    if 'Dutch' in lang_selector.text:
                        count += 1
                    if 'Bengali' in lang_selector.text:
                        count += 1
                    if 'Punjabi' in lang_selector.text:
                        count += 1
                    if 'Sign' in lang_selector.text:
                        count += 1
                    if 'Polish' in lang_selector.text:
                        count += 1
                    if 'Tagalog' in lang_selector.text:
                        count += 1
                    if 'Swedish' in lang_selector.text:
                        count += 1
                    if 'Finnish' in lang_selector.text:
                        count += 1
                    if 'Hungarian' in lang_selector.text:
                        count += 1
                        #lang_selector = len(driver.find_elements_by_class_name('_rk98a2')
                        #if driver.find_element_by_class_name('_rk98a2').text == 'Hosted ':
                        #print(lang_selector)

                    elif not any(x in lang_selector.text for x in lang_list):
                        count += 0
                else:
                    count += 0
                listing_dict['Languages'] = str(count)
    elif len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div')) > 0:
        for actual_lang_selector in driver.find_elements_by_class_name('_h6avcp2'):
            if 'Languages' in actual_lang_selector.text:
                listing_dict['Languages'] = actual_lang_selector.text
    
    listing_list.append(listing_dict.copy())
    
    
    
    #---COULDN'T GET TO LOOP BACK THROUGH HOME PAGE AND CLOSE CURRENT PAGE----
#     window_back = driver.window_handles[0]
#     driver.switch_to.window(window_back)
    
#     driver.close()
#     window_back = driver.window_handles[1]
#     close_current_window = driver.close()
    #driver.close()
    #break
    
page_dict = pd.DataFrame(listing_list)
page_dict
#python_button = driver.find_element_by_xpath('//*[@id="site-content"]/div/div/div/div[4]/div/div/div/div[2]/div/div/div/div[2]/div/div/div') 
#python_button.click() 
#time.sleep(5)
#timeout = 20?


#window_after = driver.window_handles[1]
#driver.switch_to.window(window_after)
    
#     dictionary
#     if len(driver.find_elements_by_xpath('//*[@id="Section5"]/div/div/div/div/section/div/div/div/div/div/div[3]/div/div[2]/div[2]/div[2]')) > 0:
#         groupsize_selector = driver.find_element_by_xpath('//*[@id="Section5"]/div/div/div/div/section/div/div/div/div/div/div[3]/div/div[2]/div[2]/div[2]')
#         listing['GroupSize'] = groupsize_selector.text
#     else:
#         listing['GroupSize'] = 'n/a'

# listing_list.append(listing_dict)
# driver.close()
# Out:
#                                                   URLs  Tags  \
# 0    https://www.airbnb.com/experiences/223773?loca...   2.0
# 1    https://www.airbnb.com/experiences/358969?loca...   2.0
# 2    https://www.airbnb.com/experiences/1140666?loc...   2.0
# 3    https://www.airbnb.com/experiences/522186?loca...   NaN
# 4    https://www.airbnb.com/experiences/1005288?loc...   3.0
# ..                                                 ...   ...
# 995  https://www.airbnb.com/experiences/278438?loca...   1.0
# 996  https://www.airbnb.com/experiences/225907?loca...   2.0
# 997  https://www.airbnb.com/experiences/1158495?loc...   2.0
# 998  https://www.airbnb.com/experiences/93984?locat...   NaN
# 999  https://www.airbnb.com/experiences/377804?loca...   1.0
#
#                                       GroupSize  Host_photos Food Drinks  \
# 0                                Up to 2 people            5    1      1
# 1                                Up to 4 people            5    1      1
# ...

# %%
pickled_individual_page_df = page_dict.to_pickle('./individual_pages.pkl')
#unpickled_individual_page_df = pd.read_pickle('./dummy.pkl')
#na_food = unpickled_individual_page_df[unpickled_individual_page_df['Food'] == 'n/a']
#na_food
#unpickled_individual_page_df['Drinks'].isna().value_counts()

# %%
unpickled_individual_page_df['GroupSize_splice_up_to'] = unpickled_individual_page_df['GroupSize'].apply(lambda x: x.split('Up to ')[1])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# URLs           1000 non-null object
# Tags           783 non-null float64
# GroupSize      999 non-null object
# Host_photos    1000 non-null int64
# Food           312 non-null object
# Drinks         516 non-null object
# Languages      999 non-null object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 54.8+ KB

# %%
driver.get('https://www.airbnb.com/experiences/522186?location=crafts%20classes&source=p2')

for actual_lang_selector in driver.find_elements_by_class_name('_h6avcp2'):
    if 'Languages' in actual_lang_selector.text:
        listing_dict['Languages'] = actual_lang_selector.text
#     else: 
#         listing_dict['Languages'] = 'n/a'
listing_dict['Languages']
# Out:
# 'Languages:\nOffered in English'

# %%
dict_ = {}
list_ = []
for x in range(0, 100):
    dict_[1] = x
    list_.append(dict_)
    dict_ = {}
print(list_)

# %%
list_test = [dict(zip([1],[x])) for x in range(1,100)]
list_test

# %%
# for url in python_button:
# # window_back = driver.window_handles[0]
# # driver.switch_to.window(window_back)
#     #create a list of dictionaries for each page
#     listing_list = []
#     listing_dict = {}
    
#     url.click()
#     #pause between clicks to each url on the page
#     time.sleep(10)
#     #switch driver to new window 
#     window_after = driver.window_handles[1]
#     driver.switch_to.window(window_after)

#     #URLs
#     listing_dict['URLs'] = driver.find_element_by_xpath('/html/head/meta[7]')

# listing_dict

for url in driver.find_elements_by_class_name('_1s5t6bf8'):
    #Dictionary of url's (to merge with other list)
    url_selector = driver.find_element_by_xpath('//a[@href]').text
    print()
    #listing_dict['URL'] = url_selector
    #url = [x.get_attribute("href") for x in url_selector] 
    #listing_dict['URLs'] = url
#     del urls[:2]
#     #urls.pop()
#     start_page_dict['URLs'] = urls
    

# listing_dict['URLs'] = driver.find_element_by_xpath('/html/head/link[7]').text

# listing_dict['test'] = 'hello'
listing_dict
#driver.find_element_by_xpath('//*[@id="site-content"]/div/div/div/div[4]/div/div/div/div[2]/div/div/div/div[2]/div/div/div').text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-7e19eadf604f> in <module>
#      33
#      34 # listing_dict['test'] = 'hello'
# ---> 35 listing_dict
#      36 #driver.find_element_by_xpath('//*[@id="site-content"]/div/div/div/div[4]/div/div/div/div[2]/div/div/div/div[2]/div/div/div').text
#
# NameError: name 'listing_dict' is not defined

# %%
if len(driver.find_elements_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div')) > 0:
        for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div'):
            if driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div').text == 'Drinks':
                listing_dict['Drinks'] = 1
            elif driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div').text == 'Food':
                listing_dict['Food'] = 1
        for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div'):
            if driver.find_element_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div').text == 'Drinks':
                listing_dict['Drinks'] = 1
            elif driver.find_element_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div').text == 'Food':
                listing_dict['Food'] = 1
        for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div'):
            if driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div').text == 'Drinks':
                listing_dict['Drinks'] = 1
            elif driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div').text == 'Food':
                listing_dict['Food'] = 1
        for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-3"]/div/div[1]/div'):
            if driver.find_element_by_xpath('//*[@id="amenities-card-3"]/div/div[1]/div').text == 'Drinks':
                listing_dict['Drinks'] = 1
            elif driver.find_element_by_xpath('//*[@id="amenities-card-3"]/div/div[1]/div').text == 'Food':
                listing_dict['Food'] = 1
        for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-4"]/div/div[1]/div'):
            if driver.find_element_by_xpath('//*[@id="amenities-card-4"]/div/div[1]/div').text == 'Drinks':
                listing_dict['Drinks'] = 1
            elif driver.find_element_by_xpath('//*[@id="amenities-card-4"]/div/div[1]/div').text == 'Food':
                listing_dict['Food'] = 1
        for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-5"]/div/div[1]/div'):
            if driver.find_element_by_xpath('//*[@id="amenities-card-5"]/div/div[1]/div').text == 'Drinks':
                listing_dict['Drinks'] = 1
            elif driver.find_element_by_xpath('//*[@id="amenities-card-5"]/div/div[1]/div').text == 'Food':
                listing_dict['Food'] = 1
                
listing_dict
listing_list = []
listing_list.append(listing_dict)
listing_list

# %%
page_dict = pd.DataFrame(listing_list)
page_dict

# %%
listtest = [1,3,3,5]
list_of_dict = []
dicttest = {}
dict_value_list = []
for x in listtest:
    if x == 1:
        dict_value_list.append('Yes') 
    else:
        dict_value_list.append('No')
dicttest['One'] = dict_value_list
list_of_dict.append(dicttest)
print(list_of_dict)

# %%
#for Selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.chrome.options import Options

#for BeautifulSoup
from bs4 import BeautifulSoup
import re

import pandas as pd
import os

import chromedriver_binary


driver = webdriver.Chrome()
driver.get("https://www.airbnb.com/s/Craft-class/experiences?refinement_paths%5B%5D=%2Fexperiences%2FKG%2FTag%3A438&search_type=search_query&screen_size=large")

start_page_dict = {}
rating_value_list = []

all_listings_ratings_section_selector = driver.find_elements_by_class_name('_1sny8g3')

# for ratings_section in all_listings_ratings_section_selector:
#     if ratings_section.text == '':
#         rating_value_list.append('n/a')
#     else:
#         rating_selector = driver.find_elements_by_class_name('_s667uw2')
#         for rating in rating_selector:
#             rating_value_list.append(rating.text)                

start_page_dict['Ratings'] = rating_value_list


#start_page_list.append(start_page_dict)
print(start_page_dict['Ratings'])

# %%
new_list = []
list_of_elements = driver.find_elements_by_class_name('_1sny8g3')
for x in list_of_elements:
    if x.text == '':
        new_list.append('n/a')
    else:
        new_list.append(x.text)
print(new_list)

# %%
rating_value_list = []
all_listings_ratings_section_selector = driver.find_elements_by_class_name('_1sny8g3')

for ratings_section in all_listings_ratings_section_selector:
    if ratings_section.text == '':
        rating_value_list.append('n/a')
    else:
        rating_value_list.append(ratings_section.text)
#         rating_selector = driver.find_elements_by_class_name('_s667uw2')
#         for rating in rating_selector:
#             rating_value_list.append(rating.text)
        

rating_value_list

# %%
x = []
y = [1,2,3]
z = ['a','b']
for wtf in y:
    if wtf == 3:
        x.append('yes')
    else:
        x.append('no')
        #for why_me in z:
            #x.append(why_me)
print(x)

# %%
listtest = [1,3,3,5]
list_of_dict = []
dicttest = {}
dict_value_list = []
for x in listtest:
    if 6:
        dict_value_list.append('Yes') 
    else:
        dict_value_list.append('No')
dicttest['One'] = dict_value_list
list_of_dict.append(dicttest)
print(list_of_dict)

# %%
mylist = [1,2,3,4,5]
del mylist[:1]
mylist.pop()
mylist

# %%
    
    #if statement --> break
    python_button = driver.find_elements_by_class_name('_1s5t6bf8')
    for i in python_button:
        i.click() 
        time.sleep(10)

        #dictionary
        listing_dict = {}
        if len(driver.find_elements_by_xpath('//*[@id="Section5"]/div/div/div/div/section/div/div/div/div/div/div[3]/div/div[2]/div[2]/div[2]')) > 0:
            groupsize_selector = driver.find_element_by_xpath('//*[@id="Section5"]/div/div/div/div/section/div/div/div/div/div/div[3]/div/div[2]/div[2]/div[2]')
            listing['GroupSize'] = groupsize_selector.text
        else:
            listing['GroupSize'] = 'n/a'

    listing_list.append(listing_dict)
    driver.close()

    #defaultdict(str)  
pd.DataFrame(list_list)

# %%
driver.get('https://www.airbnb.com/experiences/518579?location=Craft%20class&source=p2')
#driver.get('https://www.airbnb.com/experiences/1029847?location=Craft%20class&source=p2')

# %%
#window_after = driver.window_handles[1]
#driver.switch_to.window(window_after)

listing_list = []
listing_dict = {}

if len(driver.find_elements_by_class_name('_17zvmwh2')) > 0:
    for actual_groupsize in driver.find_elements_by_class_name('_17zvmwh2'):
        if 'Up to' in actual_groupsize.text:
            listing_dict['GroupSize'] = actual_groupsize.text
                #listing_dict ['GroupSize'] = driver.find_element_by_class_name('_17zvmwh2').text
                #groupsize_selector = driver.find_element_by_class_name('_17zvmwh2')
                #listing_dict['GroupSize'] = groupsize_selector.text
        #else:
            #listing_dict['GroupSize'] = 'n/a'
        #elif not any('Up to' in actual_groupsize.text):
            #listing_dict['GroupSize'] = 'n/a'
#else:
    #listing_dict['GroupSize'] = 'n/a'
print(listing_dict)

# %%
if len(driver.find_elements_by_class_name('_rk98a2')) > 0: 
    for actual_lang_selector in driver.find_elements_by_class_name('_rk98a2'):
        if 'Hosted' in actual_lang_selector.text:     
            for lang_selector in driver.find_elements_by_class_name('_17zvmwh2'):

                count = 0
                lang_list = ['Hungarian', 'Finnish', 'Swedish', 'Tagalog', 'Polish', 'Sign', 'Punjabi', 'Bengali', 'Dutch', 'Turkish', 'Hindi', 'Chinese', 'Mandarin', 'Russian', 'Japanese', 'French', 'Czech', 'Norwegian', 'Danish', 'Malay', 'Hebrew', 'Greek', 'Thai', 'Korean', 'Indonesian', 'Portuguese', 'Arabic', 'Spanish', 'Italian', 'German', 'English']    
                if 'English' in lang_selector.text:
                    count += 1

# %%
for i in range(1,2):
    for x in [1,2,4,6]:
        print(x)

        
listing_list = []

python_button = driver.find_elements_by_class_name('_1s5t6bf8')
page = 0
while page < 3:
    page += 1
    for i in python_button:
        i.click()        
        time.sleep(10) 

driver.close()

# %%
#for Selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

#for BeautifulSoup
from bs4 import BeautifulSoup
import re

import pandas as pd
import os

import chromedriver_binary


driver = webdriver.Chrome()
driver.get("https://www.airbnb.com/s/Craft-class/experiences?refinement_paths%5B%5D=%2Fexperiences%2FKG%2FTag%3A438&search_type=search_query&screen_size=large")

# %%
if len(driver.find_elements_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div')) > 0:
    for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div'):
        if driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div').text == 'Drinks':
            drinks = driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div')
            listing_dict['Drinks'] = 1
            listing_dict['Food'] = 'n/a'
        elif driver.find_element_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div').text == 'Drinks':
            drinks = driver.find_element_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div')
            listing_dict['Drinks'] = 1
            listing_dict['Food'] = 'n/a'
        elif driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div').text == 'Drinks':
            drinks = driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div')
            listing_dict['Drinks'] = 1
            listing_dict['Food'] = 'n/a'
        elif driver.find_element_by_xpath('//*[@id="amenities-card-3"]/div/div[1]/div').text == 'Drinks':
            drinks = driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div')
            listing_dict['Drinks'] = 1
            listing_dict['Food'] = 'n/a'    
        elif driver.find_element_by_xpath('//*[@id="amenities-card-4"]/div/div[1]/div').text == 'Drinks':
            drinks = driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div')
            listing_dict['Drinks'] = 1
            listing_dict['Food'] = 'n/a'     
        elif driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div').text == 'Food':
            food = driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div')
            listing_dict['Drinks'] = 'n/a'
            listing_dict['Food'] = 1
        elif driver.find_element_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div').text == 'Food':
            food = driver.find_element_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div')
            listing_dict['Drinks'] = 'n/a'
            listing_dict['Food'] = 1
        elif driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div').text == 'Food':
            food = driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div')
            listing_dict['Drinks'] = 'n/a'
            listing_dict['Food'] = 1
        elif driver.find_element_by_xpath('//*[@id="amenities-card-3"]/div/div[1]/div').text == 'Food':
            food = driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div')
            listing_dict['Drinks'] = 'n/a'
            listing_dict['Food'] = 1
        elif driver.find_element_by_xpath('//*[@id="amenities-card-4"]/div/div[1]/div').text == 'Food':
            food = driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div')
            listing_dict['Drinks'] = 'n/a'
            listing_dict['Food'] = 1
            
    #<div class="_h6avcp2">Drinks<!-- --> <span class="_8tbpu3" aria-hidden="true">󲀃</span></div>
elif len(driver.find_elements_by_class_name('_h6avcp2')) > 0:
    for included_selector in driver.find_elements_by_class_name('_h6avcp2'):
        drink_count = 0
        food_count = 0
        if 'Drinks' in included_selector.text:     
        #for drink_selector in driver.find_elements_by_class_name('_h6avcp2'):
            #count = 0
        #if 'Drinks' in actual_drink_selector.text:
         #       count += 1
          #  else:
        #        count += 0
            drink_count += 1
        if 'Food' in included_selector.text:
            food_count += 1
    #print(driver.find_element_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div').text)
        if drink_count == 1:
            listing_dict['Drinks'] = 1
        if food_count == 1:
            listing_dict['Food'] = 1
            
        #for lang_selector in driver.find_elements_by_class_name('Drinks'):
        #if driver.find_element_by_class_name('_h6avcp2').text == 'Drinks':
            #drinks = driver.find_element_by_class_name('_h6avcp2')
        #print('Drinks:'+str(count)) 
        #print('Food:'+str(count))
        #elif driver.find_element_by_class_name('_h6avcp2').text == 'Food':
            #food = driver.find_element_by_class_name('_h6avcp2')
            #print('Drinks: n/a')
            #print('Food: 1')
    #elif len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]')) > 0:
    #photo_count = len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]'))
else:
    listing_dict['Drinks'] = 'n/a'
    listing_dict['Food'] = 'n/a'
print(listing_dict)

# %%
def ExtractText(Xpath):
    textlist = []
    for item in range(1,10):
        textlist.append(driver.find_elements_by_xpath('//div/div/a/div/div[2]/div[1]/div[3]/div/div/ul/li[1]'+'[%d]'%item).text)
    return textlist
ExtractText()

# %%
x = driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div').text
x

# %% [markdown]
# # Prices from Start Page

# %%
prices = []
price_selector = driver.find_elements_by_xpath('//div/div/a/div/div[2]/div[1]/div[3]/div/div/ul/li[1]')
#print(driver.find_element_by_xpath(price_selector).text)

prices = [x.text for x in price_selector] 
print(prices)
    #list_price_anchor = price_anchor.text
    #list_price_anchor_filtered = list(filter(lambda x: x.isdigit(), list_price_anchor))
    #print(list_price_anchor_filtered)
#len(list_price_anchor)

# %% [markdown]
# # Ratings from Start Page

# %%
ratings = []
rating_selector = driver.find_elements_by_class_name('_s667uw2')

ratings = [x.text for x in rating_selector] 
print(ratings)
#for rating_anchor in driver.find_elements_by_xpath(rating_selector):
    #print(rating_anchor.text)

# %% [markdown]
# # Duration from Start Page

# %%
durations = []
duration_selector = driver.find_elements_by_xpath('//div/div/a/div/div[2]/div[1]/div[3]/div/div/ul/li[2]')

durations = [x.text for x in duration_selector] 
print(durations)

# %%
duration_selector = '//div/div/a/div/div[2]/div[1]/div[3]/div/div/ul/li[2]'
#print(driver.find_element_by_xpath(price_selector).text)

for duration_anchor in driver.find_elements_by_xpath(duration_selector):
    print(duration_anchor.text)
split_duration_anchor = duration_anchor.text.split('·', -100)
print(split_duration_anchor)

# %% [markdown]
# # Experience Title from Start Page

# %%
for rating_selector in driver.find_elements_by_class_name('_1s5t6bf8'):
    print(rating_selector.text)

titles = []
title_selector = driver.find_elements_by_class_name('_1s5t6bf8')

durations = [x.text for x in duration_selector] 
print(durations)

# %% [markdown]
# # City from Start Page

# %%
for rating_selector in driver.find_elements_by_class_name('_13qcgpja'):
    print(rating_selector.text)
    
    list--> create digctionary per page --> end append dictionary to list
    url or title

# %% [markdown]
# # Find Link and Open New Page

# %%
#python_button = driver.find_element_by_xpath('//*[@id="site-content"]/div/div/div/div[4]/div/div/div/div[2]/div/div/div/div[2]/div/div/div') 
#python_button.click() 
#time.sleep(5)
#timeout = 20?


#window_after = driver.window_handles[1]
#driver.switch_to.window(window_after)

#group size
if len(driver.find_elements_by_xpath('//*[@id="Section5"]/div/div/div/div/section/div/div/div/div/div/div[3]/div/div[2]/div[2]/div[2]')) > 0:
    groupsize_selector = driver.find_element_by_xpath('//*[@id="Section5"]/div/div/div/div/section/div/div/div/div/div/div[3]/div/div[2]/div[2]/div[2]')
    print('GroupSize:'+groupsize_selector.text)
else:
    print('GroupSize: n/a')


#number of tags
if len(driver.find_elements_by_class_name('_9grdxv')) > 0:
    tag_selector = len(driver.find_elements_by_class_name('_9grdxv'))
    print('Tags:'+str(tag_selector))
else:
    print('Tags: n/a')
#https://www.airbnb.com/experiences/931883?location=craft%20class&source=p2
#//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div[5]/div/div[2]/div #https://www.airbnb.com/experiences/242309?source=p2
#//*[@id="Section5"]/div/div/div/div/section/div/div/div/div/div/div[3]/div/div[4]/div[2]/div[2]
    #//*[@id="Section5"]/div/div/div/div/section/div/div/div/div/div/div[3]/div/div[3]/div[2]/div[2]
    
#<div class="_h6avcp2"><span class="_krjbj">Languages:</span>Offered in German, English and Italian</div>
#number of languages    
if len(driver.find_elements_by_class_name('_rk98a2')) > 0: 
    for actual_lang_selector in driver.find_elements_by_class_name('_rk98a2'):
        if 'Hosted' in actual_lang_selector.text:     
            for lang_selector in driver.find_elements_by_class_name('_17zvmwh2'):

                count = 0
                lang_list = ['Hungarian', 'Finnish', 'Swedish', 'Tagalog', 'Polish', 'Sign', 'Punjabi', 'Bengali', 'Dutch', 'Turkish', 'Hindi', 'Chinese', 'Mandarin', 'Russian', 'Japanese', 'French', 'Czech', 'Norwegian', 'Danish', 'Malay', 'Hebrew', 'Greek', 'Thai', 'Korean', 'Indonesian', 'Portuguese', 'Arabic', 'Spanish', 'Italian', 'German', 'English']    
                if 'English' in lang_selector.text:
                    count += 1
                if 'German' in lang_selector.text:
                    count += 1
                if 'Italian' in lang_selector.text:
                    count += 1
                if 'Spanish' in lang_selector.text:
                    count += 1
                if 'Arabic' in lang_selector.text:
                    count += 1
                if 'Portuguese' in lang_selector.text:
                    count += 1
                if 'Indonesian' in lang_selector.text:
                    count += 1
                if 'Korean' in lang_selector.text:
                    count += 1
                if 'Thai' in lang_selector.text:
                    count += 1
                if 'Greek' in lang_selector.text:
                    count += 1
                if 'Hebrew' in lang_selector.text:
                    count += 1
                if 'Malay' in lang_selector.text:
                    count += 1
                if 'Danish' in lang_selector.text:
                    count += 1
                if 'Norwegian' in lang_selector.text:
                    count += 1
                if 'Czech' in lang_selector.text:
                    count += 1
                if 'French' in lang_selector.text:
                    count += 1
                if 'Japanese' in lang_selector.text:
                    count += 1
                if 'Russian' in lang_selector.text:
                    count += 1
                if 'Chinese' in lang_selector.text:
                    count += 1
                    #^^^this is a modification of Airbnb list 'Chinese (Simplified)', since I'm using an 'in' statement--which should cover all listings with the word 'Chinese'
                if 'Mandarin' in lang_selector.text:
                    count += 1
                    #^^^this is a guess of how it can be displayed 
                if 'Hindi' in lang_selector.text:
                    count += 1
                if 'Turkish' in lang_selector.text:
                    count += 1
                if 'Dutch' in lang_selector.text:
                    count += 1
                if 'Bengali' in lang_selector.text:
                    count += 1
                if 'Punjabi' in lang_selector.text:
                    count += 1
                if 'Sign' in lang_selector.text:
                    count += 1
                if 'Polish' in lang_selector.text:
                    count += 1
                if 'Tagalog' in lang_selector.text:
                    count += 1
                if 'Swedish' in lang_selector.text:
                    count += 1
                if 'Finnish' in lang_selector.text:
                    count += 1
                if 'Hungarian' in lang_selector.text:
                    count += 1
                    #lang_selector = len(driver.find_elements_by_class_name('_rk98a2')
                    #if driver.find_element_by_class_name('_rk98a2').text == 'Hosted ':
                    #print(lang_selector)

                elif not any(x in lang_selector.text for x in lang_list):
                    count += 0
            else:
                count += 0
            print('Lang:'+str(count))
elif len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div')) > 0:
    for actual_lang_selector in driver.find_elements_by_class_name('_h6avcp2'):
    if 'Languages' in actual_lang_selector.text:
        print('Lang:'+actual_lang_selector.text)
    else: 
        print('Lang: n/a')
    #for actual_lang_selector in driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div'):
        #if 'Offered in' actual_lang_selector.text:
            #print('hello')

##Use below to fix above
    for actual_lang_selector in driver.find_elements_by_class_name('_rk98a2'):
        if 'Hosted' in actual_lang_selector.text:     
            for lang_selector in driver.find_elements_by_class_name('_17zvmwh2'):

                count = 0
                lang_list = ['Hungarian', 'Finnish', 'Swedish', 'Tagalog', 'Polish', 'Sign', 'Punjabi', 'Bengali', 'Dutch', 'Turkish', 'Hindi', 'Chinese', 'Mandarin', 'Russian', 'Japanese', 'French', 'Czech', 'Norwegian', 'Danish', 'Malay', 'Hebrew', 'Greek', 'Thai', 'Korean', 'Indonesian', 'Portuguese', 'Arabic', 'Spanish', 'Italian', 'German', 'English']    
                if 'English' in lang_selector.text:
                    count += 1
            #lang_num_selector = len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div[6]/div/div[2]/div')) 
            #print('Langs:'+str(lang_num_selector))
#//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div[6]/div/div[2]/div #https://www.airbnb.com/experiences/647476?location=craft%20class&source=p2
#number of experiences/(and stays or guests?) hosted
#<div class="_1p3joamp"><span class="_1b1p6ls">2</span></div>
#<span class="_1b1p6ls">7</span> #https://www.airbnb.com/experiences/931883?location=craft%20class&source=p2
#//*[@id="Section8"]/div/div/div/section/div/div[2]/section/div[4]/div[3]/div[1]/span #https://www.airbnb.com/experiences/931883?location=craft%20class&source=p2
#//*[@id="Section8"]/div/div/div/section/div/div[2]/section/div[4]/div[2]/div[1]
#host_count_selector = driver.find_element_by_xpath('//*[@id="Section8"]/div/div/div/section/div/div[2]/section/div[4]/div')
#print(host_count_selector.text)

    
#NEED TO WORK ON
#//*[@id="Section8"]/div/div/div/section/div/div[2]/section/div[4]/div[3]/div[1]/span #https://www.airbnb.com/experiences/166953?source=p2
#if len(driver.find_elements_by_xpath('//*[@id="Section8"]/div/div/div/section/div/div[2]/section/div[4]/')) > 0:
#    host_count_selector = driver.find_element_by_xpath('//*[@id="Section8"]/div/div/div/section/div/div[2]/section/div[4]/')
#    print('Host_count:'+host_count_selector.text)
#//*[@id="Section8"]/div/div/div/section/div/div[2]/section/div[4]/div[2]/div[1] #https://www.airbnb.com/experiences/324425?location=craft%20class&source=p2
#//*[@id="Section8"]/div/div/div/section/div/div[2]/section/div[4]/div[3]/div[1]/span #https://www.airbnb.com/experiences/931883?location=craft%20class&source=p2
#elif len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]')) > 0:
    #photo_count = len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]'))
#else:
#    print('Host_count: n/a')
    #//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]
#number of host photos
#for photo_selector in driver.find_elements_by_xpath('//*[@id="FMP-target"]'):
#script = "return $(\"td:contains('{}')\").length".format(text="Silver")
#count = driver.execute_script(script)
if len(driver.find_elements_by_xpath('//*[@id="FMP-target"]')) > 0:
    photo_count_selector = len(driver.find_elements_by_xpath('//*[@id="FMP-target"]'))
elif len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]')) > 0:
    photo_count_selector = len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]'))
else:
    photo_count_selector = 0
print('Host_photos:'+str(photo_count_selector))
    
#//*[@id="Section14"]/div/div/div/section/div/div[2]/section/div/div/div/div/div/div/div/a/div/div[1]/div/div/div/div/div/div/img
#<div class="_5azyco5"><div class="_tk908t"><button type="button" aria-label="Previous" class="_gem7oc6"><div class="_n0qiwy"><svg viewBox="0 0 18 18" role="img" aria-label="Previous" focusable="false" style="height: 19px; width: 19px; display: block; fill: rgb(255, 255, 255);"><path d="m13.7 16.29a1 1 0 1 1 -1.42 1.41l-8-8a1 1 0 0 1 0-1.41l8-8a1 1 0 1 1 1.42 1.41l-7.29 7.29z" fill-rule="evenodd"></path></svg></div></button><button type="button" aria-label="Next" class="_1rftspj9"><div class="_grtzc2"><svg viewBox="0 0 18 18" role="img" aria-label="Next" focusable="false" style="height: 19px; width: 19px; display: block; fill: rgb(255, 255, 255);"><path d="m4.29 1.71a1 1 0 1 1 1.42-1.41l8 8a1 1 0 0 1 0 1.41l-8 8a1 1 0 1 1 -1.42-1.41l7.29-7.29z" fill-rule="evenodd"></path></svg></div></button></div></div> #https://www.airbnb.com/experiences/117290?location=craft%20class&source=p2
#//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1] ##https://www.airbnb.com/experiences/117290?location=craft%20class&source=p2 
#<div class="_x682mss"><div class="_tk908t"><button type="button" aria-label="Previous" class="_gem7oc6"><div class="_n0qiwy"><svg viewBox="0 0 18 18" role="img" aria-label="Previous" focusable="false" style="height: 19px; width: 19px; display: block; fill: rgb(255, 255, 255);"><path d="m13.7 16.29a1 1 0 1 1 -1.42 1.41l-8-8a1 1 0 0 1 0-1.41l8-8a1 1 0 1 1 1.42 1.41l-7.29 7.29z" fill-rule="evenodd"></path></svg></div></button><button type="button" aria-label="Next" class="_1rftspj9"><div class="_grtzc2"><svg viewBox="0 0 18 18" role="img" aria-label="Next" focusable="false" style="height: 19px; width: 19px; display: block; fill: rgb(255, 255, 255);"><path d="m4.29 1.71a1 1 0 1 1 1.42-1.41l8 8a1 1 0 0 1 0 1.41l-8 8a1 1 0 1 1 -1.42-1.41l7.29-7.29z" fill-rule="evenodd"></path></svg></div></button></div></div> #https://www.airbnb.com/experiences/647476?location=craft%20class&source=p2
#//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1] #https://www.airbnb.com/experiences/647476?location=craft%20class&source=p2
#<img class="_91slf2a" style="object-fit:cover" aria-hidden="true" alt="Show full-screen, host-provided image" id="FMP-target" src="https://a0.muscache.com/im/pictures/lombard/MtTemplate-1140666-media_library/original/1fe64dff-fcc0-4cd9-8ce3-ec40674d74de.jpeg?aki_policy=exp_md">  https://www.airbnb.com/experiences/1140666?location=craft%20class&source=p2
#//*[@id="FMP-target"] # https://www.airbnb.com/experiences/1140666?location=craft%20class&source=p2
#<img class="_91slf2a" style="object-fit:cover" aria-hidden="true" alt="Show full-screen, host-provided image" id="FMP-target" src="https://a0.muscache.com/im/pictures/lombard/MtTemplate-1140666-media_library/original/dc62d875-3407-410f-85cb-005213ad3f05.jpeg?aki_policy=exp_md">  # https://www.airbnb.com/experiences/1140666?location=craft%20class&source=p2
#//*[@id="FMP-target"] # https://www.airbnb.com/experiences/1140666?location=craft%20class&source=p2


##DIFFERENT DISPLAYS: IF/ELSE/OR statements!!! 
#//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div[15]/div[1]/div[2]/div/div/div[1]/div[1]/text()
#drinks

if len(driver.find_elements_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div')) > 0:
    for included_selector in driver.find_elements_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div'):
        if driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div').text == 'Drinks':
            drinks = driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div')
            print('Drinks: 1')
            print('Food: n/a')
        elif driver.find_element_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div').text == 'Drinks':
            drinks = driver.find_element_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div')
            print('Drinks: 1')
            print('Food: n/a')
        elif driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div').text == 'Food':
            food = driver.find_element_by_xpath('//*[@id="amenities-card-0"]/div/div[1]/div')
            print('Drinks: n/a')
            print('Food: 1')
        elif driver.find_element_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div').text == 'Food':
            food = driver.find_element_by_xpath('//*[@id="amenities-card-1"]/div/div[1]/div')
            print('Drinks: n/a')
            print('Food: 1')
        elif driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div').text == 'Drinks':
            drinks = driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div')
            print('Drinks: 1')
            print('Food: n/a')
        elif driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div').text == 'Food':
            food = driver.find_element_by_xpath('//*[@id="amenities-card-2"]/div/div[1]/div')
            print('Drinks: n/a')
            print('Food: 1')
#<div class="_h6avcp2">Drinks<!-- --> <span class="_8tbpu3" aria-hidden="true">󲀃</span></div>
elif len(driver.find_elements_by_class_name('_h6avcp2')) > 0:
    for included_selector in driver.find_elements_by_class_name('_h6avcp2'):
        drink_count = 0
        food_count = 0
        if 'Drinks' in included_selector.text:     
        #for drink_selector in driver.find_elements_by_class_name('_h6avcp2'):
            #count = 0
        #if 'Drinks' in actual_drink_selector.text:
         #       count += 1
          #  else:
        #        count += 0
            drink_count += 1
        if 'Food' in included_selector.text:
            food_count += 0
    #print(driver.find_element_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div').text)
        if drink_count == 1:
            print('Drinks: 1')
        if food_count == 1:
            print('Food: 1')
            break
    #for lang_selector in driver.find_elements_by_class_name('Drinks'):
        #if driver.find_element_by_class_name('_h6avcp2').text == 'Drinks':
            #drinks = driver.find_element_by_class_name('_h6avcp2')
        #print('Drinks:'+str(count)) 
        #print('Food:'+str(count))
        #elif driver.find_element_by_class_name('_h6avcp2').text == 'Food':
            #food = driver.find_element_by_class_name('_h6avcp2')
            #print('Drinks: n/a')
            #print('Food: 1')
    #elif len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]')) > 0:
    #photo_count = len(driver.find_elements_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[1]/div/div/div/div/aside/div[2]/div/div[2]/div[1]'))
else:
    print('Drinks: n/a')
    print('Food: n/a')
    #//*[@id="amenities-card-0"]/div
    #//*[@id="amenities-card-0"]/div/div[1]/div
    #<div class="_1p3joamp">Food</div>
#//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div[14]/div[1]/div[2]/div/div/div[2]/div[1]/text() #https://www.airbnb.com/experiences/117290?location=craft%20class&source=p2
#//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div[15]/div[1]/div[2]/div/div/div[1]/div[1]/text()
#//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div[14]/div[1]/div[2]/div/div/div[2]/div[1] #https://www.airbnb.com/experiences/117290?location=craft%20class&source=p2  
#<div class="_h6avcp2"><span class="_krjbj">Includes:</span>Food, Drinks and Equipment</div>  #https://www.airbnb.com/experiences/117290?location=craft%20class&source=p2
#<div class="_1p3joamp">Drinks</div> #https://www.airbnb.com/experiences/931883?location=craft%20class&source=p2
#//*[@id="amenities-card-0"]/div/div[1]/div #https://www.airbnb.com/experiences/931883?location=craft%20class&source=p2

# %%
for actual_drinks_selector in driver.find_elements_by_class_name('_h6avcp2'):
    count = 0
    if 'Drinks' in actual_drinks_selector.text:     
        #for drink_selector in driver.find_elements_by_class_name('_h6avcp2'):
            #count = 0
        #if 'Drinks' in actual_drink_selector.text:
         #       count += 1
          #  else:
        #        count += 0
        count += 1

    #print(driver.find_element_by_xpath('//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div').text)
    if count == 1:
        break
    print(1)
    


#//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div[15]/div[1]/div[2]/div/div/div[1]/div[1]/text()
#//*[@id="Section16"]/div/div/div/section/div/div[2]/section/div[15]/div[1]/div[2]/div/div/div[1]/div[2]/div

# %%
driver.get('https://www.airbnb.com/experiences/117290?location=craft%20class&source=p2')
for actual_lang_selector in driver.find_elements_by_class_name('_h6avcp2'):
    if 'Languages' in actual_lang_selector.text:
        print(actual_lang_selector.text)
    #"https://www.airbnb.com/experiences/117290?location=craft%20class&source=p2")
    #"https://www.airbnb.com/experiences/242309?source=p2")
        #https://www.airbnb.com/experiences/532337?location=craft%20class&source=p2

# %% [markdown]
# #Selenium hands of the source of the specific job page to Beautiful Soup
# soup_level2=BeautifulSoup(driver.text, 'lxml')
# #Beautiful Soup grabs the HTML table on the page
# table = soup_level2.find_all('table')
# #Beautiful Soup sends to Pandas
# table

# %%
driver = webdriver.Chrome()

driver.get("https://www.airbnb.com/s/craft-class/experiences?refinement_paths%5B%5D=%2Fexperiences%2FKG%2FTag%3A438&current_tab_id=experience_tab&selected_tab_id=experience_tab&search_type=filter_change&screen_size=large&hide_dates_and_guests_filters=false")
time.sleep(5)

# %%
python_button = driver.find_element_by_xpath('//*[@id="site-content"]/div/div/div/div[4]/div/div/div/div[2]/div/div/div/div[2]/div/div/div') 
python_button.click() 
time.sleep(5)
window_after = driver.window_handles[1]
driver.switch_to.window(window_after)


groupsize_selector = '//*[@id="Section5"]/div/div/div/div/section/div/div/div/div/div/div[3]/div/div[2]/div[2]/div[2]'
print(driver.find_element_by_xpath(groupsize_selector).text)

#for groupsize_selector in driver.find_element_by_xpath('//*[@id="Section5"]/div/div/div/div/section/div/div/div/div/div/div[3]/div/div[2]/div[2]/div[2]'):
    #print(groupsize_selector.text)

# %% [markdown]
# # EXCEPTIONS
# "Food, Drink, Equipment--separately listed snacks" https://www.airbnb.com/experiences/117290?location=craft%20class&source=p2
# "All languages welcome" https://www.airbnb.com/experiences/647476?location=craft%20class&source=p2
# Videos instead of number of pictures https://www.airbnb.com/experiences/875018?location=Craft%20class&source=p2

# %%
pages = 1500

for page in range(1,pages):
    url = "http://quotes.toscrape.com/js/page/" + str(page) + "/"

    driver.get(url)

    items = len(driver.find_elements_by_class_name("quote"))

    total = []
    for item in range(items):
        quotes = driver.find_elements_by_class_name("quote")
        for quote in quotes:
            quote_text = quote.find_element_by_class_name('text').text
            author = quote.find_element_by_class_name('author').text
            new = ((quote_text,author))
            total.append(new)
    df = pd.DataFrame(total,columns=['quote','author'])
    
driver.close()
    
#https://dev.to/lewiskori/beginner-s-guide-to-web-scraping-with-python-s-selenium-3fl9

# %% [markdown]
# # ----DO NOT USE-----

# %%
elm = driver.find_element_by_tag_name('html')
elm.send_keys(Keys.END)
time.sleep(8)
elm.send_keys(Keys.HOME)

# %%
def parse(self):

    last_height = self.driver.execute_script("return document.body.scrollHeight")
    SCROLL_PAUSE_TIME = 7
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        sleep(SCROLL_PAUSE_TIME)
        new_height = self.driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
        sleep(1.2)
parse(driver)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import sys

import unittest, time, re

class Sel(unittest.TestCase):
    def setUp(self):
        self.driver = webdriver.Chrome()
        self.driver.implicitly_wait(30)
        self.base_url = "https://twitter.com"
        self.verificationErrors = []
        self.accept_next_alert = True
    def test_sel(self):
        driver = self.driver
        delay = 3
        driver.get(self.base_url + "/search?q=stackoverflow&src=typd")
        driver.find_element_by_link_text("All").click()
        for i in range(1,100):
            self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(4)
        html_source = driver.page_source
        data = html_source.encode('utf-8')


if __name__ == "__main__":
    unittest.main()

#https://stackoverflow.com/questions/22702277/crawl-site-that-has-infinite-scrolling-using-python

# %%
import os
import logging
import argparse
from bs4 import BeautifulSoup
from selenium import webdriver
from time import gmtime, strftime

# Define logger format
LOGGER_FORMAT = '%(levelname)s:%(asctime)s:%(name)s:%(message)s'
TIME = strftime("%m%d_%H%M", gmtime())

# Define logger and stream handler - no file handler
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
formatter = logging.Formatter(LOGGER_FORMAT)
stream_handler = logging.StreamHandler()
stream_handler.setFormatter(formatter)
logger.addHandler(stream_handler)


# Function to scrape from airbnb property link.
# Returns: Property name and type, room type, number of bedrooms
#   number of bathrooms and amenities
def airbnb_scraper(response_source):
    """Scraper for AirBnB website
    :param response_source: Source from browser
    :return: File with the property name, property type, number
        of bedrooms, number of bathrooms and list of amenities.
    """

    html_soup = BeautifulSoup(response_source, "html.parser")
    page_description = html_soup.findAll("div", {"class": "room__dls"})[0]
    room_details = page_description.findAll("div", {"id": "details"})[0]

    # Get property name
    property_name = page_description.find("div", {"itemprop": "name"}).text

    # Get basic details
    property_type = room_details.find(text="Property type:").parent.find("strong").text
    room_type = room_details.find(text="Room type:").parent.find("strong").text
    n_bedrooms = room_details.find(text="Bedrooms:").parent.find("strong").text
    n_bathrooms = room_details.find(text="Bathrooms:").parent.find("strong").text

    # Get amenities list
    amenities_section = room_details.findAll("div", {"class": "amenities"})[0]
    all_amenities = amenities_section.findAll("div", {"class": "expandable-content expandable-content-full"})[0]
    amenities = '|'.join([element.text for element in all_amenities.findAll("strong")])

    return {
        'property_name': property_name,
        'property_type': property_type,
        'room_type': room_type,
        'n_bedrooms': n_bedrooms,
        'n_bathrooms': n_bathrooms,
        'amenities': amenities
    }


# Function to handle the links being processed.
# These are loaded from the links file data obtained from the
# scraper being used and saved in file.
def links_handler(links_file, out_type):
    """ Links handler
    Loads property links from links_file and saves the results of the
    scaper in a results file
    """
    file_type = out_type.lower()
    save_file_headers = 'Property Name, Property Type, Room Type, Number of Bedrooms, Number of Bathrooms, Amenities\n'

    # Open save file with name airbnb_properties_$time.out_type
    if file_type == 'csv':
        save_file = open('results_{}.csv'.format(TIME), 'w')
        save_file.write(save_file_headers)
    else:
        raise ValueError('Out-type {} not found'.format(file_type))

    # Open browser for javascript rendering
    browser = webdriver.PhantomJS(service_log_path=os.path.devnull)

    # Iterate through links and save values
    with open(links_file) as file:
        for property_link in file:
            browser.get(property_link)
            # Get property details using the requested scraper
            # For other website types introduce another scraper.
            # Example - bookingdotcom_scraper(property_link)
            property_details = airbnb_scraper(browser.page_source)
            logger.info('Property details loaded')

            #for item_name, item_value in property_details.items():
            #    print('{}:\t{}'.format(item_name, item_value))

            # Save values
            property_details_values = list(property_details.values())
            if file_type == 'csv':
                save_file.write(','.join(property_details_values) + '\n')
            logger.info('Property details saved')

    # Close browser
    browser.quit()

    # Close save file
    save_file.close()


if __name__ == "__main__":
    parser = argparse.ArgumentParser()

    parser.add_argument('--links-file',
                        required=True,
                        type=str,
                        help='Local dir with the links for the properties in .txt format')

    parser.add_argument('--out-type',
                        default='csv',
                        type=str,
                        help='Output file type for scraping results')

    parse_args, unknown = parser.parse_known_args()

    # If unknown arguments found, warn them on the console
    logger.warning('Unknown arguments: {}'.format(unknown))
    links_handler(**parse_args.__dict__)
